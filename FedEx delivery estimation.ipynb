# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\gopib\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv(r"C:\Users\gopib\Downloads\FedEx dataset\fedex.csv")
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 0        2008      1           3          4                2003.0
# 1        2008      1           3          4                 754.0
# 2        2008      1           3          4                 628.0
# 3        2008      1           3          4                 926.0
# 4        2008      1           3          4                1829.0
# ...       ...    ...         ...        ...                   ...
# 3604170  2008      6          19          4                1059.0
# 3604171  2008      6          19          4                 555.0
# 3604172  2008      6          19          4                 821.0
# 3604173  2008      6          19          4                 718.0
# 3604174  2008      6          19          4                1127.0
#
#          Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  \
# 0                         1955                   2225           WN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3604175 entries, 0 to 3604174
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Year                   int64
#  1   Month                  int64
#  2   DayofMonth             int64
#  3   DayOfWeek              int64
#  4   Actual_Shipment_Time   float64
#  5   Planned_Shipment_Time  int64
#  6   Planned_Delivery_Time  int64
#  7   Carrier_Name           object
#  8   Carrier_Num            int64
#  9   Planned_TimeofTravel   float64
#  10  Shipment_Delay         float64
#  11  Source                 object
#  12  Destination            object
#  13  Distance               int64
#  14  Delivery_Status        float64
# dtypes: float64(4), int64(8), object(3)
# memory usage: 412.5+ MB

# %%
df.isnull().sum()
# Out:
# Year                         0
# Month                        0
# DayofMonth                   0
# DayOfWeek                    0
# Actual_Shipment_Time     81602
# Planned_Shipment_Time        0
# Planned_Delivery_Time        0
# Carrier_Name                 0
# Carrier_Num                  0
# Planned_TimeofTravel       547
# Shipment_Delay           81602
# Source                       0
# Destination                  0
# Distance                     0
# Delivery_Status          81602
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df = df.drop_duplicates()

# %%
def convert_to_minutes(time):
    hours = time//100
    minutes = time%100
    return hours * 60 + minutes

# %%
df['Actual_Shipment_Time'] = df['Actual_Shipment_Time'].apply(convert_to_minutes)
# Out:
# C:\Users\gopib\AppData\Local\Temp\ipykernel_23888\862178241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Actual_Shipment_Time'] = df['Actual_Shipment_Time'].apply(convert_to_minutes)

# %%
df['Planned_Shipment_Time'] = df['Planned_Shipment_Time'].apply(convert_to_minutes)
# Out:
# C:\Users\gopib\AppData\Local\Temp\ipykernel_23888\1352270750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Planned_Shipment_Time'] = df['Planned_Shipment_Time'].apply(convert_to_minutes)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 0  2008      1           3          4                1203.0
# 1  2008      1           3          4                 474.0
# 2  2008      1           3          4                 388.0
# 3  2008      1           3          4                 566.0
# 4  2008      1           3          4                1109.0
#
#    Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  Carrier_Num  \
# 0                   1195                   2225           WN          335
# 1                    455                   1000           WN         3231
# 2                    380                    750           WN          448
# 3                    570                   1100           WN         1746
# 4                   1075                   1925           WN         3920
#
#    Planned_TimeofTravel  Shipment_Delay Source Destination  Distance  \
# 0                 150.0             8.0    IAD         TPA       810
# ...

# %%
df['Planned_Delivery_Time'] = df['Planned_Delivery_Time'].apply(convert_to_minutes)
# Out:
# C:\Users\gopib\AppData\Local\Temp\ipykernel_23888\828014074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Planned_Delivery_Time'] = df['Planned_Delivery_Time'].apply(convert_to_minutes)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 0  2008      1           3          4                1203.0
# 1  2008      1           3          4                 474.0
# 2  2008      1           3          4                 388.0
# 3  2008      1           3          4                 566.0
# 4  2008      1           3          4                1109.0
#
#    Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  Carrier_Num  \
# 0                   1195                   1345           WN          335
# 1                    455                    600           WN         3231
# 2                    380                    470           WN          448
# 3                    570                    660           WN         1746
# 4                   1075                   1165           WN         3920
#
#    Planned_TimeofTravel  Shipment_Delay Source Destination  Distance  \
# 0                 150.0             8.0    IAD         TPA       810
# ...

# %%
df['Delivery_Status'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
import sweetviz

# %%
#viz = sweetviz.analyze(df)

# %%
#viz.show_html('FedEx_report.html')

# %%
df['Delivery_Status'].value_counts()
# Out:
# Delivery_Status
# 0.0    2804357
# 1.0     718212
# Name: count, dtype: int64

# %%
df['Delivery_Status'].isnull().sum()
# Out:
# 81602

# %%
df['Delivery_Status'].dropna()
# Out:
# 0          0.0
# 1          1.0
# 2          0.0
# 3          0.0
# 4          1.0
#           ...
# 3604170    0.0
# 3604171    0.0
# 3604172    0.0
# 3604173    0.0
# 3604174    1.0
# Name: Delivery_Status, Length: 3522569, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3604171 entries, 0 to 3604174
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Year                   int64
#  1   Month                  int64
#  2   DayofMonth             int64
#  3   DayOfWeek              int64
#  4   Actual_Shipment_Time   float64
#  5   Planned_Shipment_Time  int64
#  6   Planned_Delivery_Time  int64
#  7   Carrier_Name           object
#  8   Carrier_Num            int64
#  9   Planned_TimeofTravel   float64
#  10  Shipment_Delay         float64
#  11  Source                 object
#  12  Destination            object
#  13  Distance               int64
#  14  Delivery_Status        float64
# dtypes: float64(4), int64(8), object(3)
# memory usage: 440.0+ MB

# %%
df[df['Delivery_Status'].isnull()]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 178      2008      1           3          4                   NaN
# 373      2008      1           3          4                   NaN
# 399      2008      1           3          4                   NaN
# 401      2008      1           3          4                   NaN
# 415      2008      1           3          4                   NaN
# ...       ...    ...         ...        ...                   ...
# 3603242  2008      6          18          3                   NaN
# 3603243  2008      6          18          3                   NaN
# 3603246  2008      6          18          3                   NaN
# 3603849  2008      6          19          4                   NaN
# 3603996  2008      6          19          4                   NaN
#
#          Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  \
# 178                        420                    510           WN
# ...

# %%
df = df.dropna(subset = ['Delivery_Status'])

# %%
df[['Source']].value_counts()
# Out:
# Source
# ATL       203765
# ORD       168683
# DFW       136555
# DEN       118909
# LAX       110068
#            ...
# AKN           41
# BJI           25
# INL           24
# GST           23
# TUP           10
# Name: count, Length: 297, dtype: int64

# %%
df.isna().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# Actual_Shipment_Time       0
# Planned_Shipment_Time      0
# Planned_Delivery_Time      0
# Carrier_Name               0
# Carrier_Num                0
# Planned_TimeofTravel     406
# Shipment_Delay             0
# Source                     0
# Destination                0
# Distance                   0
# Delivery_Status            0
# dtype: int64

# %%
df['Delivery_Status'] = df['Delivery_Status'].astype(int)

# %%
continuous = ["Actual_Shipment_Time","Planned_Shipment_Time","Planned_Delivery_Time","Planned_TimeofTravel","Shipment_Delay","Distance"]
nominal = ["Carrier_Name","Source","Destination"]
ordinal = ["Year","Month","DayofMonth","DayOfWeek"]

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, PowerTransformer, OneHotEncoder

# %%
cont_transform = Pipeline([("Mean Imputation",SimpleImputer(strategy='mean')),
         ("Transformation",PowerTransformer(method='yeo-johnson',standardize=True))])
nominal_transform = Pipeline([("Mode Imputation",SimpleImputer(strategy='most_frequent')),
         ("One Hot Encoding",OneHotEncoder(drop='first'))])
ordinal_transform = Pipeline([("Mode Imputation",SimpleImputer(strategy='most_frequent'))])


preprocess = ColumnTransformer([("Continuous Transformation",cont_transform,continuous),
                  ("Nominal Transformation",nominal_transform,nominal),
                  ("Ordinal Transformation",ordinal_transform,ordinal)],remainder='passthrough')

preprocess
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Continuous Transformation',
#                                  Pipeline(steps=[('Mean Imputation',
#                                                   SimpleImputer()),
#                                                  ('Transformation',
#                                                   PowerTransformer())]),
#                                  ['Actual_Shipment_Time',
#                                   'Planned_Shipment_Time',
#                                   'Planned_Delivery_Time',
#                                   'Planned_TimeofTravel', 'Shipment_Delay',
#                                   'Distance']),
#                                 ('Nominal Transformation',
#                                  Pipeline(steps=[('Mode Imputation',
#                                                   SimpleImputer(strategy='most_frequent')),
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df.drop('Delivery_Status',axis = 1)
y = df['Delivery_Status']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1 = Pipeline([("Data Preprocessing",preprocess),
         ("Algorithm",LogisticRegression())])

model1
# Out:
# Pipeline(steps=[('Data Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Continuous Transformation',
#                                                   Pipeline(steps=[('Mean '
#                                                                    'Imputation',
#                                                                    SimpleImputer()),
#                                                                   ('Transformation',
#                                                                    PowerTransformer())]),
#                                                   ['Actual_Shipment_Time',
#                                                    'Planned_Shipment_Time',
#                                                    'Planned_Delivery_Time',
#                                                    'Planned_TimeofTravel',
#                                                    'Shipment_Delay',
# ...

# %%
model1.fit(X_train,y_train)
y_pred = model1.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\gopib\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9824205054832126

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2 = Pipeline([("Data Preprocessing",preprocess),
         ("Algorithm",LogisticRegression())])

model2
# Out:
# C:\Users\gopib\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('Data Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Continuous Transformation',
#                                                   Pipeline(steps=[('Mean '
#                                                                    'Imputation',
# ...

# %%
model2.fit(X_train,y_train)
y_pred = model2.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\gopib\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9824205054832126

# %%
import pickle
pickle.dump(model1,open("delivery_status.pkl",'wb'))
test = pickle.load(open("delivery_status.pkl",'rb'))
test
# Out:
# C:\Users\gopib\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('Data Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Continuous Transformation',
#                                                   Pipeline(steps=[('Mean '
#                                                                    'Imputation',
# ...
